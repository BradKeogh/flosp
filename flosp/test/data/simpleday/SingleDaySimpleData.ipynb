# %%
import pandas as pd
import numpy as np

# %% [markdown]
# PSEUDONYMISED_PATIENT_ID,AGE_AT_ARRIVAL,GENDER_NATIONAL_DESCRIPTION,SITE,ARRIVAL_DTTM,ARRIVAL_MODE_NATIONAL_CODE,TRIAGE_ASSESSMENT_DTTM,FIRSTDOC_FOR_TREATMENT_DTTM,ADM_REQUEST_DTTM,ADM_REQUEST_LOC_DESCRIPTION,ADMISSION_FLAG,DEPARTURE_DTTM,STREAM_LOCAL_CODE
# 4484,56,Female,HOSPITAL1,2013-08-04 09:59:00,2.0,2013-08-01 10:52:00,2013-08-01 12:41:00,,,0,2013-08-03 12:22:00,MIN

# %% [markdown]
# # ED

# %%
np.random.seed(7)

# %%
size = 24

# %%
def make_datetime_array(size):
    datetimes = []
    j = 0

    for i in np.arange(size):

        new = pd.datetime(2018,1,1,j,5)
        j+=1
        datetimes.append(new)
    return datetimes

#make_datetime_array(size)
#datetimes

# %%
arrival_array = make_datetime_array(size)

# %%
ED_data = {
'PSEUDONYMISED_PATIENT_ID':np.arange(0,size),
'AGE_AT_ARRIVAL':np.random.randint(18,100,size),
'GENDER_NATIONAL_DESCRIPTION':[1]*size,
'SITE':['HOSPITAL']*size,
'ARRIVAL_DTTM':arrival_array,
'ARRIVAL_MODE_NATIONAL_CODE':[1]*size,
'TRIAGE_ASSESSMENT_DTTM':[np.datetime64()] * size,
'FIRSTDOC_FOR_TREATMENT_DTTM':[np.datetime64()] * size,
'ADM_REQUEST_DTTM':[np.datetime64()] * size,
'ADM_REQUEST_LOC_DESCRIPTION':['inpatient']*size,
'ADMISSION_FLAG':[1]*size,
'DEPARTURE_DTTM':[np.datetime64()] * size,
'STREAM_LOCAL_CODE':['MAJORS']* size,
}

# %%
dfED = pd.DataFrame(data=ED_data)
dfED.head()
# Out:
#    ADMISSION_FLAG ADM_REQUEST_DTTM ADM_REQUEST_LOC_DESCRIPTION  \
# 0               1              NaT                   inpatient
# 1               1              NaT                   inpatient
# 2               1              NaT                   inpatient
# 3               1              NaT                   inpatient
# 4               1              NaT                   inpatient
#
#    AGE_AT_ARRIVAL        ARRIVAL_DTTM  ARRIVAL_MODE_NATIONAL_CODE  \
# 0              65 2018-01-01 00:05:00                           1
# 1              86 2018-01-01 01:05:00                           1
# 2              43 2018-01-01 02:05:00                           1
# 3              85 2018-01-01 03:05:00                           1
# 4              41 2018-01-01 04:05:00                           1
#
#   DEPARTURE_DTTM FIRSTDOC_FOR_TREATMENT_DTTM  GENDER_NATIONAL_DESCRIPTION  \
# 0            NaT                         NaT                            1
# 1            NaT                         NaT                            1
# 2            NaT                         NaT                            1
# 3            NaT                         NaT                            1
# 4            NaT                         NaT                            1
#
#    PSEUDONYMISED_PATIENT_ID      SITE STREAM_LOCAL_CODE TRIAGE_ASSESSMENT_DTTM
# 0                         0  HOSPITAL            MAJORS                    NaT
# 1                         1  HOSPITAL            MAJORS                    NaT
# 2                         2  HOSPITAL            MAJORS                    NaT
# 3                         3  HOSPITAL            MAJORS                    NaT
# 4                         4  HOSPITAL            MAJORS                    NaT

# %% [markdown]
# #### fill blank datetime columns

# %%
dfED.TRIAGE_ASSESSMENT_DTTM = dfED.ARRIVAL_DTTM + pd.Timedelta(10,'m')
dfED.FIRSTDOC_FOR_TREATMENT_DTTM = dfED.ARRIVAL_DTTM + pd.Timedelta(10,'m')
dfED.ADM_REQUEST_DTTM = dfED.ARRIVAL_DTTM + pd.Timedelta(45,'m')
dfED.DEPARTURE_DTTM = dfED.ARRIVAL_DTTM + pd.Timedelta(60,'m')

# %%
dfED.to_csv('./SimpleED.csv',index=False)

# %% [markdown]
# # IP

# %%
size = 3

# %%
arrival_array = make_datetime_array(size)

# %%
IP_data = {
'PSEUDONYMISED_PATIENT_ID':np.arange(0,size) + 100,
'SPELL_ID':np.arange(0,size),
'AGE_AT_ARRIVAL':np.random.randint(18,100,size),
'GENDER_NATIONAL_DESCRIPTION':[1] * size,
'SITE':['HOSPITAL']*size,
'ADM_DTTM':arrival_array,
'ADM_SOURCE_CODE':[1] * size,
'ADM_METHOD':[1] * size,
'DIS_DTTM':[np.datetime64()] * size,
'DIS_DESTINATION':['home'] * size,
'DIS_METHOD':[1] * size,
'MOVE_NUMBER':[1] * size,
'MOVE_START':[np.datetime64()] * size,
'MOVE_END':[np.datetime64()] * size,
'MOVE_NAME':['WARD'] * size,
'SPELL_LOS':[np.nan]*size
}

# %%
dfIP = pd.DataFrame(data=IP_data)
dfIP.head()
# Out:
#              ADM_DTTM  ADM_METHOD  ADM_SOURCE_CODE  AGE_AT_ARRIVAL  \
# 0 2018-01-01 00:05:00           1                1              87
# 1 2018-01-01 01:05:00           1                1              74
# 2 2018-01-01 02:05:00           1                1              42
#
#   DIS_DESTINATION DIS_DTTM  DIS_METHOD  GENDER_NATIONAL_DESCRIPTION MOVE_END  \
# 0            home      NaT           1                            1      NaT
# 1            home      NaT           1                            1      NaT
# 2            home      NaT           1                            1      NaT
#
#   MOVE_NAME  MOVE_NUMBER MOVE_START  PSEUDONYMISED_PATIENT_ID      SITE  \
# 0      WARD            1        NaT                       100  HOSPITAL
# 1      WARD            1        NaT                       101  HOSPITAL
# 2      WARD            1        NaT                       102  HOSPITAL
#
#    SPELL_ID  SPELL_LOS
# 0         0        NaN
# 1         1        NaN
# 2         2        NaN

# %% [markdown]
# #### cycle through each entry and create the ward move data

# %%
newdf = dfIP.copy()
for index, row in dfIP.iterrows():
#     print(index,row)
    #### input ward start and end to old record
    
    newdf.loc[index,'MOVE_START'] = newdf.loc[index]['ADM_DTTM']
    move_datetime = newdf.loc[index]['ADM_DTTM'] + pd.Timedelta(24,'h')
    newdf.loc[index,'MOVE_END'] = move_datetime
    
    #### make new record with start and end record

    row['MOVE_START'] = move_datetime # set move start

    moveend_datetime = newdf.loc[index]['MOVE_END'] + pd.Timedelta(48,'h') # add time to previous move end
    row.loc['MOVE_END'] = moveend_datetime
    newdf = newdf.append(row)
    newdf.reset_index(inplace=True,drop=True)
    
    #### set DIS_DTTM in all records from largest 'MOVE_END'
    spell_id = newdf.loc[index]['SPELL_ID']
    newdf.loc[newdf[newdf['SPELL_ID'] == spell_id].index,'DIS_DTTM'] = moveend_datetime
    
    
newdf.head()
# Out:
#              ADM_DTTM  ADM_METHOD  ADM_SOURCE_CODE  AGE_AT_ARRIVAL  \
# 0 2018-01-01 00:05:00           1                1              87
# 1 2018-01-01 01:05:00           1                1              74
# 2 2018-01-01 02:05:00           1                1              42
# 3 2018-01-01 00:05:00           1                1              87
# 4 2018-01-01 01:05:00           1                1              74
#
#   DIS_DESTINATION            DIS_DTTM  DIS_METHOD  \
# 0            home 2018-01-04 00:05:00           1
# 1            home 2018-01-04 01:05:00           1
# 2            home 2018-01-04 02:05:00           1
# 3            home 2018-01-04 00:05:00           1
# 4            home 2018-01-04 01:05:00           1
#
#    GENDER_NATIONAL_DESCRIPTION            MOVE_END MOVE_NAME  MOVE_NUMBER  \
# 0                            1 2018-01-02 00:05:00      WARD            1
# 1                            1 2018-01-02 01:05:00      WARD            1
# 2                            1 2018-01-02 02:05:00      WARD            1
# 3                            1 2018-01-04 00:05:00      WARD            1
# 4                            1 2018-01-04 01:05:00      WARD            1
#
#            MOVE_START  PSEUDONYMISED_PATIENT_ID      SITE  SPELL_ID  SPELL_LOS
# 0 2018-01-01 00:05:00                       100  HOSPITAL         0        NaN
# 1 2018-01-01 01:05:00                       101  HOSPITAL         1        NaN
# 2 2018-01-01 02:05:00                       102  HOSPITAL         2        NaN
# 3 2018-01-02 00:05:00                       100  HOSPITAL         0        NaN
# 4 2018-01-02 01:05:00                       101  HOSPITAL         1        NaN

# %%
newdf.to_csv('./SimpleIP.csv',index=False)

# %%
spell_id
# Out:
# 0

# %%
newdf['SPELL_ID'] == spell_id
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: SPELL_ID, dtype: bool

# %%
# Out:
#    index            ADM_DTTM  ADM_METHOD  ADM_SOURCE_CODE  AGE_AT_ARRIVAL  \
# 0      0 2018-01-01 00:05:00           1                1              29
# 1      1 2018-01-01 01:05:00           1                1              50
# 2      2 2018-01-01 02:05:00           1                1              58
# 3      0 2018-01-01 00:05:00           1                1              29
# 4      1 2018-01-01 01:05:00           1                1              50
# 5      2 2018-01-01 02:05:00           1                1              58
#
#   DIS_DESTINATION DIS_DTTM  DIS_METHOD  GENDER_NATIONAL_DESCRIPTION  \
# 0            home      NaT           1                            1
# 1            home      NaT           1                            1
# 2            home      NaT           1                            1
# 3            home      NaT           1                            1
# 4            home      NaT           1                            1
# 5            home      NaT           1                            1
#
#              MOVE_END MOVE_NAME  MOVE_NUMBER          MOVE_START  \
# 0 2018-01-02 00:05:00      WARD            1 2018-01-01 00:05:00
# 1 2018-01-02 01:05:00      WARD            1 2018-01-01 01:05:00
# 2 2018-01-02 02:05:00      WARD            1 2018-01-01 02:05:00
# 3                 NaT      WARD            1 2018-01-02 00:05:00
# 4                 NaT      WARD            1 2018-01-02 01:05:00
# 5                 NaT      WARD            1 2018-01-02 02:05:00
#
#    PSEUDONYMISED_PATIENT_ID      SITE  SPELL_ID  SPELL_LOS
# 0                       100  HOSPITAL         0        NaN
# 1                       101  HOSPITAL         1        NaN
# 2                       102  HOSPITAL         2        NaN
# 3                       100  HOSPITAL         0        NaN
# 4                       101  HOSPITAL         1        NaN
# 5                       102  HOSPITAL         2        NaN

# %%
nrec = dfIP.loc[0]

# %%
row['ADM_DTTM'] = 5

# %%
row
# Out:
# ADM_DTTM                              5
# ADM_METHOD                            1
# ADM_SOURCE_CODE                       1
# AGE_AT_ARRIVAL                       58
# DIS_DESTINATION                    home
# DIS_DTTM                            NaT
# DIS_METHOD                            1
# GENDER_NATIONAL_DESCRIPTION           1
# MOVE_END                            NaT
# MOVE_NAME                          WARD
# MOVE_NUMBER                           1
# MOVE_START                          NaT
# PSEUDONYMISED_PATIENT_ID            102
# SITE                           HOSPITAL
# SPELL_ID                              2
# SPELL_LOS                           NaN
# Name: 2, dtype: object

# %%
dfIP.append(nrec)
# Out:
#              ADM_DTTM  ADM_METHOD  ADM_SOURCE_CODE  AGE_AT_ARRIVAL  \
# 0 2018-01-01 00:05:00           1                1              74
# 1 2018-01-01 01:05:00           1                1              66
# 2 2018-01-01 02:05:00           1                1              61
# 0 2018-01-01 00:05:00           1                1              74
#
#   DIS_DESTINATION DIS_DTTM  DIS_METHOD  GENDER_NATIONAL_DESCRIPTION MOVE_END  \
# 0            home      NaT           1                            1      NaT
# 1            home      NaT           1                            1      NaT
# 2            home      NaT           1                            1      NaT
# 0            home      NaT           1                            1      NaT
#
#   MOVE_NAME  MOVE_NUMBER MOVE_START  PSEUDONYMISED_PATIENT_ID      SITE  \
# 0      WARD            1        NaT                         0  HOSPITAL
# 1      WARD            1        NaT                         1  HOSPITAL
# 2      WARD            1        NaT                         2  HOSPITAL
# 0      WARD            1        NaT                         0  HOSPITAL
#
#    SPELL_LOS
# 0        NaN
# 1        NaN
# 2        NaN
# 0        NaN
