# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
from hospital import *

# %%
hh = hosp('hh')
# Out:
# ----------------------------------------
# Created hosp class instance:  hh
# ----------------------------------------
# --------------------
# Patient fileload:
# --------------------
# Found:  hhEDpat.pkl
# Missing:  hhIPpat.pkl
# --------------------
# Daily fileload:
# --------------------
# Missing:  hhEDday.pkl
# Missing:  hhIPday.pkl

# %%
df = hh.pat.get_ED()

# %%
ts = df.groupby('arrive_date').count()['hosp_patid']

# %%
ts.plot()

# %%
pd.to_datetime(ts.index)
# Out:
# DatetimeIndex(['2012-08-01', '2012-08-02', '2012-08-03', '2012-08-04',
#                '2012-08-05', '2012-08-06', '2012-08-07', '2012-08-08',
#                '2012-08-09', '2012-08-10',
#                ...
#                '2018-01-31', '2018-02-01', '2018-02-02', '2018-02-03',
#                '2018-02-04', '2018-02-05', '2018-02-06', '2018-02-07',
#                '2018-02-08', '2018-02-09'],
#               dtype='datetime64[ns]', name='arrive_date', length=2019, freq=None)

# %%
ts = ts.reset_index(level=0)

# %%
ts.dtypes
# Out:
# arrive_date    object
# hosp_patid      int64
# dtype: object

# %%
ts = ts[:-1]

# %%
ts.arrive_date = pd.to_datetime(ts.arrive_date)

# %%
ts['year'] = ts.arrive_date.apply(lambda x : x.year)

# %%
ts['month'] = ts.arrive_date.apply(lambda x : x.month)

# %%
month_descr = ts.groupby(['year','month']).describe().reset_index()

# %%
month_descr.head()
# Out:
#    year month hosp_patid                                                       \
#                    count        mean        std    min     25%    50%     75%
# 0  2012     8       31.0  242.580645  22.855742  202.0  227.00  240.0  253.00
# 1  2012     9       30.0  253.833333  20.299623  229.0  240.00  247.5  268.50
# 2  2012    10       31.0  243.161290  26.604632  201.0  218.50  238.0  264.50
# 3  2012    11       30.0  242.300000  20.027825  210.0  226.25  241.0  254.25
# 4  2012    12       31.0  234.483871  25.409803  190.0  219.50  225.0  251.00
#
#
#      max
# 0  288.0
# 1  305.0
# 2  290.0
# 3  283.0
# 4  293.0

# %%
month_descr['hosp_patid'].columns = list(month_descr.columns.levels[1])[:-1]

# %%
month_descr.head()
# Out:
#    year month hosp_patid                                                       \
#                    count        mean        std    min     25%    50%     75%
# 0  2012     8       31.0  242.580645  22.855742  202.0  227.00  240.0  253.00
# 1  2012     9       30.0  253.833333  20.299623  229.0  240.00  247.5  268.50
# 2  2012    10       31.0  243.161290  26.604632  201.0  218.50  238.0  264.50
# 3  2012    11       30.0  242.300000  20.027825  210.0  226.25  241.0  254.25
# 4  2012    12       31.0  234.483871  25.409803  190.0  219.50  225.0  251.00
#
#
#      max
# 0  288.0
# 1  305.0
# 2  290.0
# 3  283.0
# 4  293.0

# %%
col_names = ['year','month'] + list(month_descr.columns.levels[1])[:-1]

# %%
month_descr = pd.DataFrame(month_descr.as_matrix(),columns=col_names)

# %%
ts = ts.merge(month_descr,on = ['year','month'])

# %%
ts.rename(columns={'hosp_patid':'patient_count'},inplace=True)

# %%
ts.set_index('arrive_date',inplace=True)

# %%
ts.head()
# Out:
#              patient_count  year month  count        mean        std    min  \
# arrive_date
# 2012-08-01             249  2012     8   31.0  242.580645  22.855742  202.0
# 2012-08-02             225  2012     8   31.0  242.580645  22.855742  202.0
# 2012-08-03             241  2012     8   31.0  242.580645  22.855742  202.0
# 2012-08-04             240  2012     8   31.0  242.580645  22.855742  202.0
# 2012-08-05             263  2012     8   31.0  242.580645  22.855742  202.0
#
#                25%    50%    75%    max
# arrive_date
# 2012-08-01   227.0  240.0  253.0  288.0
# 2012-08-02   227.0  240.0  253.0  288.0
# 2012-08-03   227.0  240.0  253.0  288.0
# 2012-08-04   227.0  240.0  253.0  288.0
# 2012-08-05   227.0  240.0  253.0  288.0

# %% [markdown]
# #### calc sdev flag

# %%
ts.loc[ts[ts.patient_count >= ts['50%'] + 1.2*ts['std']].index,'flag_sd'] = 1

# %%
ts.flag_sd.value_counts()
# Out:
# 1.0    290
# Name: flag_sd, dtype: int64

# %%
print('Percentage of flagged: ' + str(100*ts.flag_sd.value_counts().values[0]/ts.shape[0]) )
# Out:
# Percentage of flagged: 14.3706640238

# %% [markdown]
# #### calc rolling worst prev 5 days in month?

# %%
ax = plt.subplot()
ts['patient_count'].plot(ax=ax,figsize=(18,6))

ts[ts.flag_sd == 1]['patient_count'].plot(ax=ax,style='.r')

# %%
ax = plt.subplot()
ts[-300:]['patient_count'].plot(ax=ax,figsize=(18,6))

ts[-300:][ts.flag_sd == 1]['patient_count'].plot(ax=ax,style='.r')
# Out:
# C:\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Create features

# %%
import featuretools as ft
#import utils
#from utils import load_nyc_taxi_data, compute_features, preview, feature_importances
#from sklearn.ensemble import GradientBoostingRegressor
from featuretools.primitives import (Weekend, Minute, Hour, Day, Week, Month,
                                     Weekday, Weekend, Count, Sum, Mean, Median, Std, Min, Max)

# %%
days_df = ts.reset_index()

# %%
days_df.sample()
# Out:
#     arrive_date  patient_count  year month  count        mean        std  \
# 972  2015-03-31            256  2015     3   31.0  276.806452  31.620056
#
#        min    25%    50%    75%    max  flag_sd
# 972  225.0  253.5  271.0  294.0  352.0      NaN

# %%
pat
# Out:
# hospital.pat

# %%
atten_df = hh.pat.get_ED()

# %%
atten_df.head(1)
# Out:
#    hosp_patid  age  gender  site     arrive_datetime  arrive_mode  \
# 0      489709   43  Female  BNHH 2012-08-01 00:04:00          2.0
#
#   first_triage_datetime   first_dr_datetime first_adm_request_time  \
# 0   2012-08-01 00:18:00 2012-08-01 02:24:00                    NaN
#
#   adm_referral_loc     ...      depart_weekday_name depart_year depart_date  \
# 0              NaN     ...                Wednesday        2012  2012-08-01
#
#    first_adm_request_datetime  arr_triage_wait arr_dr_wait arr_adm_req_wait  \
# 0                         NaT             14.0       140.0              NaN
#
#   adm_req_dep_wait dr_adm_req_wait dr_dep_wait
# 0              NaN             NaN        80.0
#
# [1 rows x 36 columns]

# %%
atten_df.arrive_date.head()
# Out:
# 0    2012-08-01
# 1    2012-08-01
# 2    2012-08-01
# 3    2012-08-01
# 4    2012-08-01
# Name: arrive_date, dtype: object

# %%
entities = {
    "days": (days_df, "arrive_date"),
    "attendances": (atten_df, "hosp_patid",'arrive_date'),
}

relationships = [("days", "arrive_date", "attendances", "arrive_date")]

# %%
trans_primitives = [Weekend]

features = ft.dfs(entities=entities,
                  relationships=relationships,
                  target_entity="days",
                  trans_primitives=trans_primitives,
                  agg_primitives=[],
                  ignore_variables={},
                  features_only=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-45-4ec74b295df0> in <module>()
#       7                   agg_primitives=[],
#       8                   ignore_variables={},
# ----> 9                   features_only=True)
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\synthesis\dfs.py in dfs(entities, relationships, entityset, target_entity, cutoff_time, instance_ids, agg_primitives, trans_primitives, allowed_paths, max_depth, ignore_entities, ignore_variables, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, verbose)
#     154     '''
#     155     if not isinstance(entityset, EntitySet):
# --> 156         entityset = EntitySet("dfs", entities, relationships)
#     157
#     158     dfs_object = DeepFeatureSynthesis(target_entity, entityset,
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\entityset.py in __init__(self, id, entities, relationships, verbose)
#      75                                        index=index_column,
#      76                                        time_index=time_column,
# ---> 77                                        variable_types=variable_types)
#      78
#      79         for relationship in relationships:
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\entityset.py in entity_from_dataframe(self, entity_id, dataframe, index, variable_types, make_index, time_index, secondary_time_index, encoding, already_sorted)
#     397                                            variable_types=variable_types,
#     398                                            encoding=encoding,
# --> 399                                            already_sorted=already_sorted)
#     400
#     401     def _import_from_dataframe(self,
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\entityset.py in _import_from_dataframe(self, entity_id, dataframe, index, variable_types, make_index, time_index, secondary_time_index, last_time_index, parse_date_cols, encoding, already_sorted)
#     494                         relationships=current_relationships,
#     495                         already_sorted=already_sorted,
# --> 496                         created_index=created_index)
#     497         return self
#     498
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\entityset.py in add_entity(self, entity_id, df, **kwargs)
#     505                         self,
#     506                         verbose=self._verbose,
# --> 507                         **kwargs)
#     508
#     509         # TODO DFS: think about if we need both list and dictionary
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\entity.py in __init__(self, id, df, entityset, variable_types, name, index, time_index, secondary_time_index, last_time_index, encoding, relationships, already_sorted, created_index, verbose)
#      67         self.last_time_index = last_time_index
#      68         super(Entity, self).__init__(id, entityset, variable_types, name, index,
# ---> 69                                      time_index, secondary_time_index, relationships, already_sorted)
#      70
#      71     def attempt_cast_index_to_int(self, index_var):
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\base_entity.py in __init__(self, id, entityset, variable_types, name, index, time_index, secondary_time_index, relationships, already_sorted)
#      81         self.convert_variable_types(inferred_variable_types)
#      82
# ---> 83         self.set_index(index)
#      84         self.set_time_index(time_index, already_sorted)
#      85         self.set_secondary_time_index(secondary_time_index)
#
# C:\Anaconda3\envs\ml\lib\site-packages\featuretools\entityset\entity.py in set_index(self, variable_id, unique)
#     546         self.df = self.df.set_index(self.df[variable_id], drop=False)
#     547         if unique:
# --> 548             assert self.df.index.is_unique, "Index is not unique on dataframe (Entity {})".format(self.id)
#     549
#     550         self.convert_variable_type(variable_id, vtypes.Index, convert_data=False)
#
# AssertionError: Index is not unique on dataframe (Entity attendances)

# %%
features
